# %%
import os
import re
import json
from bs4 import BeautifulSoup
import requests 
from lxml import etree

# %%
URL = "https://pave.niaid.nih.gov/explore/reference_genomes/human_genomes"
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <!-- Required meta tags -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <title>PaVE</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push(
#
# 	{'gtm.start': new Date().getTime(),event:'gtm.js'}
# 	);var f=d.getElementsByTagName(s)[0],
# 	j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 	'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 	})(window,document,'script','dataLayer','GTM-T2C8JDG');</script>
# <!-- End Google Tag Manager -->
# ...

# %%
# Åbnede soup og fandt denne dict som er tabellen:
dict = [{"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/V01116", "text": "V01116"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Revised", "pave_id": "HPV1REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/6281972", "text": "Clad et al., 1982"}, "species_name": "Mupapillomavirus 1", "virus_id": "HPV1"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X55964", "text": "X55964"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_001352", "text": "NC_001352"}, "notes": "null", "pave_id": "HPV2REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/1964523", "text": "Hirsch-Behnam et al., 1990"}, "species_name": "Alphapapillomavirus 4", "virus_id": "HPV2"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X74462", "text": "X74462"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV3REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8205838", "text": "Delius and Hofmann, 1994"}, "species_name": "Alphapapillomavirus 2", "virus_id": "HPV3"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X70827", "text": "X70827"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_001457", "text": "NC_001457"}, "notes": "null", "pave_id": "HPV4REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8389082", "text": "Egawa et al., 1993"}, "species_name": "Gammapapillomavirus 1", "virus_id": "HPV4"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/M17463", "text": "M17463"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Revised", "pave_id": "HPV5REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/3033892", "text": "Zachow et al., 1987"}, "species_name": "Betapapillomavirus 1", "virus_id": "HPV5"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X00203", "text": "X00203"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Revised", "pave_id": "HPV6REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/6321162", "text": "Schwarz et al., 1983"}, "species_name": "Alphapapillomavirus 10", "virus_id": "HPV6"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X74463", "text": "X74463"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_001595", "text": "NC_001595"}, "notes": "null", "pave_id": "HPV7REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8205838", "text": "Delius and Hofmann, 1994"}, "species_name": "Alphapapillomavirus 8", "virus_id": "HPV7"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/M12737", "text": "M12737"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV8REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/3009874", "text": "Fuchs et al., 1986"}, "species_name": "Betapapillomavirus 1", "virus_id": "HPV8"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X74464", "text": "X74464"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_001596", "text": "NC_001596"}, "notes": "null", "pave_id": "HPV9REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8205838", "text": "Delius and Hofmann, 1994"}, "species_name": "Betapapillomavirus 2", "virus_id": "HPV9"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X74465", "text": "X74465"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_001576", "text": "NC_001576"}, "notes": "null", "pave_id": "HPV10REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8205838", "text": "Delius and Hofmann, 1994"}, "species_name": "Alphapapillomavirus 2", "virus_id": "HPV10"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/M14119", "text": "M14119"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV11REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/3008427", "text": "Dartmann et al., 1986"}, "species_name": "Alphapapillomavirus 10", "virus_id": "HPV11"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X74466", "text": "X74466"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV12REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8205838", "text": "Delius and Hofmann, 1994"}, "species_name": "Betapapillomavirus 1", "virus_id": "HPV12"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X62843", "text": "X62843"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV13REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/1325697", "text": "Van Ranst et al., 1992"}, "species_name": "Alphapapillomavirus 10", "virus_id": "HPV13"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X74467", "text": "X74467"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Revised", "pave_id": "HPV14REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8205838", "text": "Delius and Hofmann, 1994"}, "species_name": "Betapapillomavirus 1", "virus_id": "HPV14"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X74468", "text": "X74468"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Revised", "pave_id": "HPV15REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8205838", "text": "Delius and Hofmann, 1994"}, "species_name": "Betapapillomavirus 2", "virus_id": "HPV15"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/K02718", "text": "K02718"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Revised", "pave_id": "HPV16REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/2990099", "text": "Seedorf et al., 1985"}, "species_name": "Alphapapillomavirus 9", "virus_id": "HPV16"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X74469", "text": "X74469"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Revised", "pave_id": "HPV17REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8205838", "text": "Delius and Hofmann, 1994"}, "species_name": "Betapapillomavirus 2", "virus_id": "HPV17"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X05015", "text": "X05015"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Revised", "pave_id": "HPV18REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/3039146", "text": "Cole and Danos, 1987"}, "species_name": "Alphapapillomavirus 7", "virus_id": "HPV18"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X74470", "text": "X74470"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV19REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8205838", "text": "Delius and Hofmann, 1994"}, "species_name": "Betapapillomavirus 1", "virus_id": "HPV19"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/U31778", "text": "U31778"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV20REF", "pave_name": "null", "reference": {"text": "Delius, Unpublished"}, "species_name": "Betapapillomavirus 1", "virus_id": "HPV20"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/U31779", "text": "U31779"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV21REF", "pave_name": "null", "reference": {"text": "Delius, Unpublished"}, "species_name": "Betapapillomavirus 1", "virus_id": "HPV21"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/U31780", "text": "U31780"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV22REF", "pave_name": "null", "reference": {"text": "Delius, Unpublished"}, "species_name": "Betapapillomavirus 2", "virus_id": "HPV22"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/U31781", "text": "U31781"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV23REF", "pave_name": "null", "reference": {"text": "Delius, Unpublished"}, "species_name": "Betapapillomavirus 2", "virus_id": "HPV23"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/U31782", "text": "U31782"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV24REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/6092701", "text": "Kremsdorf et al., 1984"}, "species_name": "Betapapillomavirus 1", "virus_id": "HPV24"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X74471", "text": "X74471"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV25REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8205838", "text": "Delius and Hofmann, 1994"}, "species_name": "Betapapillomavirus 1", "virus_id": "HPV25"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X74472", "text": "X74472"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_001583", "text": "NC_001583"}, "notes": "null", "pave_id": "HPV26REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8205838", "text": "Delius and Hofmann, 1994"}, "species_name": "Alphapapillomavirus 5", "virus_id": "HPV26"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X74473", "text": "X74473"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV27REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8205838", "text": "Delius and Hofmann, 1994"}, "species_name": "Alphapapillomavirus 4", "virus_id": "HPV27"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/U31783", "text": "U31783"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV28REF", "pave_name": "null", "reference": {"text": "Delius, Unpublished"}, "species_name": "Alphapapillomavirus 2", "virus_id": "HPV28"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/U31784", "text": "U31784"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV29REF", "pave_name": "null", "reference": {"text": "Delius, Unpublished"}, "species_name": "Alphapapillomavirus 2", "virus_id": "HPV29"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X74474", "text": "X74474"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV30REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8205838", "text": "Delius and Hofmann, 1994"}, "species_name": "Alphapapillomavirus 6", "virus_id": "HPV30"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/J04353", "text": "J04353"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV31REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/2545036", "text": "Goldsborough et al., 1989"}, "species_name": "Alphapapillomavirus 9", "virus_id": "HPV31"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X74475", "text": "X74475"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_001586", "text": "NC_001586"}, "notes": "null", "pave_id": "HPV32REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8205838", "text": "Delius and Hofmann, 1994"}, "species_name": "Alphapapillomavirus 1", "virus_id": "HPV32"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/M12732", "text": "M12732"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV33REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/3009902", "text": "Cole and Streeck, 1986"}, "species_name": "Alphapapillomavirus 9", "virus_id": "HPV33"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X74476", "text": "X74476"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_001587", "text": "NC_001587"}, "notes": "null", "pave_id": "HPV34REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8205838", "text": "Delius and Hofmann, 1994"}, "species_name": "Alphapapillomavirus 11", "virus_id": "HPV34"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X74477", "text": "X74477"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV35REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8205838", "text": "Delius and Hofmann, 1994"}, "species_name": "Alphapapillomavirus 9", "virus_id": "HPV35"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/U31785", "text": "U31785"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV36REF", "pave_name": "null", "reference": {"text": "Delius, Unpublished"}, "species_name": "Betapapillomavirus 1", "virus_id": "HPV36"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/U31786", "text": "U31786"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV37REF", "pave_name": "null", "reference": {"text": "Delius, Unpublished"}, "species_name": "Betapapillomavirus 2", "virus_id": "HPV37"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/U31787", "text": "U31787"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV38REF", "pave_name": "null", "reference": {"text": "Delius, Unpublished"}, "species_name": "Betapapillomavirus 2", "virus_id": "HPV38"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/M62849", "text": "M62849"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV39REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/1847266", "text": "Volpers and Streeck, 1991"}, "species_name": "Alphapapillomavirus 7", "virus_id": "HPV39"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X74478", "text": "X74478"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV40REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8205838", "text": "Delius and Hofmann, 1994"}, "species_name": "Alphapapillomavirus 8", "virus_id": "HPV40"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X56147", "text": "X56147"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_001354", "text": "NC_001354"}, "notes": "null", "pave_id": "HPV41REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/1645904", "text": "Hirt et al., 1991"}, "species_name": "Nupapillomavirus 1", "virus_id": "HPV41"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/M73236", "text": "M73236"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV42REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/1309278", "text": "Philipp et al., 1992"}, "species_name": "Alphapapillomavirus 1", "virus_id": "HPV42"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/AJ620205", "text": "AJ620205"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV43REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/2542593", "text": "Lorincz et al., 1989"}, "species_name": "Alphapapillomavirus 8", "virus_id": "HPV43"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/U31788", "text": "U31788"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV44REF", "pave_name": "null", "reference": {"text": "Delius, Unpublished"}, "species_name": "Alphapapillomavirus 10", "virus_id": "HPV44"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X74479", "text": "X74479"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV45REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8205838", "text": "Delius and Hofmann, 1994"}, "species_name": "Alphapapillomavirus 7", "virus_id": "HPV45"}, {"abbreviation": "null", "genbank": "null", "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "null", "pave_name": "null", "reference": "null", "species_name": "original HPV46 is HPV20 subtype", "virus_id": "HPV46"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/M32305", "text": "M32305"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV47REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/2162112", "text": "Kiyono et al., 1990"}, "species_name": "Betapapillomavirus 1", "virus_id": "HPV47"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/U31789", "text": "U31789"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_001690", "text": "NC_001690"}, "notes": "null", "pave_id": "HPV48REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/2552166", "text": "Muller et al., 1989"}, "species_name": "Gammapapillomavirus 2", "virus_id": "HPV48"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X74480", "text": "X74480"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_001591", "text": "NC_001591"}, "notes": "null", "pave_id": "HPV49REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8205838", "text": "Delius and Hofmann, 1994"}, "species_name": "Betapapillomavirus 3", "virus_id": "HPV49"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/U31790", "text": "U31790"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_001691", "text": "NC_001691"}, "notes": "null", "pave_id": "HPV50REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/2552168", "text": "Favre et al., 1989"}, "species_name": "Gammapapillomavirus 3", "virus_id": "HPV50"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/M62877", "text": "M62877"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV51REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/1649326", "text": "Lungu et al., 1991"}, "species_name": "Alphapapillomavirus 5", "virus_id": "HPV51"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X74481", "text": "X74481"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV52REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8205838", "text": "Delius and Hofmann, 1994"}, "species_name": "Alphapapillomavirus 9", "virus_id": "HPV52"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X74482", "text": "X74482"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_001593", "text": "NC_001593"}, "notes": "Revised", "pave_id": "HPV53REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8205838", "text": "Delius and Hofmann, 1994"}, "species_name": "Alphapapillomavirus 6", "virus_id": "HPV53"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/U37488", "text": "U37488"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_001676", "text": "NC_001676"}, "notes": "null", "pave_id": "HPV54REF", "pave_name": "null", "reference": {"text": "Delius, Unpublished"}, "species_name": "Alphapapillomavirus 13", "virus_id": "HPV54"}, {"abbreviation": "null", "genbank": "null", "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "null", "pave_name": "null", "reference": "null", "species_name": "original HPV55 is HPV44 subtype", "virus_id": "HPV55"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X74483", "text": "X74483"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Revised", "pave_id": "HPV56REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8205838", "text": "Delius and Hofmann, 1994"}, "species_name": "Alphapapillomavirus 6", "virus_id": "HPV56"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X55965", "text": "X55965"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV57REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/1964523", "text": "Hirsch-Behnam et al., 1990"}, "species_name": "Alphapapillomavirus 4", "virus_id": "HPV57"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/D90400", "text": "D90400"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV58REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/1656594", "text": "Kirii et al., 1991"}, "species_name": "Alphapapillomavirus 9", "virus_id": "HPV58"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X77858", "text": "X77858"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Revised", "pave_id": "HPV59REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8030272", "text": "Rho et al., 1994"}, "species_name": "Alphapapillomavirus 7", "virus_id": "HPV59"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/U31792", "text": "U31792"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_001693", "text": "NC_001693"}, "notes": "null", "pave_id": "HPV60REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/1326820", "text": "Matsukura et al., 1992"}, "species_name": "Gammapapillomavirus 4", "virus_id": "HPV60"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/U31793", "text": "U31793"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_001694", "text": "NC_001694"}, "notes": "null", "pave_id": "HPV61REF", "pave_name": "null", "reference": {"text": "Delius, Unpublished"}, "species_name": "Alphapapillomavirus 3", "virus_id": "HPV61"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/AY395706", "text": "AY395706"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV62REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/15346342", "text": "Fu et al., 2004"}, "species_name": "Alphapapillomavirus 3", "virus_id": "HPV62"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X70828", "text": "X70828"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_001458", "text": "NC_001458"}, "notes": "null", "pave_id": "HPV63REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8389082", "text": "Egawa et al., 1993"}, "species_name": "Mupapillomavirus 2", "virus_id": "HPV63"}, {"abbreviation": "null", "genbank": "null", "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "null", "pave_name": "null", "reference": "null", "species_name": "original HPV64 is HPV34 subtype", "virus_id": "HPV64"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X70829", "text": "X70829"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV65REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8389082", "text": "Egawa et al., 1993"}, "species_name": "Gammapapillomavirus 1", "virus_id": "HPV65"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/U31794", "text": "U31794"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV66REF", "pave_name": "null", "reference": {"text": "Delius, Unpublished"}, "species_name": "Alphapapillomavirus 6", "virus_id": "HPV66"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/D21208", "text": "D21208"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV67REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/9857984", "text": "Kirii and Matsukura, 1998"}, "species_name": "Alphapapillomavirus 9", "virus_id": "HPV67"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/DQ080079", "text": "DQ080079"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV68REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/16306621", "text": "Narechania et al., 2005"}, "species_name": "Alphapapillomavirus 7", "virus_id": "HPV68"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/AB027020", "text": "AB027020"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV69REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/10618284", "text": "Kino et al., 2000"}, "species_name": "Alphapapillomavirus 5", "virus_id": "HPV69"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/U21941", "text": "U21941"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV70REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8815087", "text": "Forslund and Hansson, 1996"}, "species_name": "Alphapapillomavirus 7", "virus_id": "HPV70"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/AB040456", "text": "AB040456"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Revised", "pave_id": "HPV71REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/11312670", "text": "Matsukura and Sugase, 2001"}, "species_name": "Alphapapillomavirus 14", "virus_id": "HPV71"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X94164", "text": "X94164"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Revised", "pave_id": "HPV72REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8635859", "text": "Volter et al., 1996"}, "species_name": "Alphapapillomavirus 3", "virus_id": "HPV72"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/X94165", "text": "X94165"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV73REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/8635859", "text": "Volter et al., 1996"}, "species_name": "Alphapapillomavirus 11", "virus_id": "HPV73"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/AF436130", "text": "AF436130"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV74REF", "pave_name": "null", "reference": {"text": "Terai and Burk, Unpublished"}, "species_name": "Alphapapillomavirus 10", "virus_id": "HPV74"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/Y15173", "text": "Y15173"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV75REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/9454709", "text": "Delius et al., 1998"}, "species_name": "Betapapillomavirus 3", "virus_id": "HPV75"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/Y15174", "text": "Y15174"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV76REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/9454709", "text": "Delius et al., 1998"}, "species_name": "Betapapillomavirus 3", "virus_id": "HPV76"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/Y15175", "text": "Y15175"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV77REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/9454709", "text": "Delius et al., 1998"}, "species_name": "Alphapapillomavirus 2", "virus_id": "HPV77"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KC138720", "text": "KC138720"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV78REF", "pave_name": "null", "reference": {"text": "Silling et al., Unpublished"}, "species_name": "Alphapapillomavirus 2", "virus_id": "HPV78"}, {"abbreviation": "null", "genbank": "null", "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "null", "pave_name": "null", "reference": "null", "species_name": "null", "virus_id": "HPV79"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/Y15176", "text": "Y15176"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV80REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/9454709", "text": "Delius et al., 1998"}, "species_name": "Betapapillomavirus 2", "virus_id": "HPV80"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/AJ620209", "text": "AJ620209"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV81REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/11312670", "text": "Matsukura and Sugase, 2001"}, "species_name": "Alphapapillomavirus 3", "virus_id": "HPV81"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/AB027021", "text": "AB027021"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Revised", "pave_id": "HPV82REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/10618284", "text": "Kino et al., 2000"}, "species_name": "Alphapapillomavirus 5", "virus_id": "HPV82"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/AF151983", "text": "AF151983"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV83REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/10405368", "text": "Brown et al., 1999"}, "species_name": "Alphapapillomavirus 3", "virus_id": "HPV83"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/AF293960", "text": "AF293960"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV84REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/11145894", "text": "Terai and Burk, 2001"}, "species_name": "Alphapapillomavirus 3", "virus_id": "HPV84"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/AF131950", "text": "AF131950"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV85REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/10580054", "text": "Chow and Leong, 1999"}, "species_name": "Alphapapillomavirus 7", "virus_id": "HPV85"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/AF349909", "text": "AF349909"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV86REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/11145894", "text": "Terai and Burk, 2001"}, "species_name": "Alphapapillomavirus 3", "virus_id": "HPV86"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/AJ400628", "text": "AJ400628"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Revised", "pave_id": "HPV87REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/11689676", "text": "Menzo et al., 2001"}, "species_name": "Alphapapillomavirus 3", "virus_id": "HPV87"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/EF467176", "text": "EF467176"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_010329", "text": "NC_010329"}, "notes": "null", "pave_id": "HPV88REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/17935140", "text": "Kullander et al., 2008"}, "species_name": "Gammapapillomavirus 5", "virus_id": "HPV88"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/AF436128", "text": "AF436128"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Revised", "pave_id": "HPV89REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/12085327", "text": "Terai and Burk, 2002"}, "species_name": "Alphapapillomavirus 3", "virus_id": "HPV89"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/AY057438", "text": "AY057438"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_004104", "text": "NC_004104"}, "notes": "null", "pave_id": "HPV90REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/12085327", "text": "Terai and Burk, 2002"}, "species_name": "Alphapapillomavirus 14", "virus_id": "HPV90"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/AF419318", "text": "AF419318"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV91REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/12085327", "text": "Terai and Burk, 2002"}, "species_name": "Alphapapillomavirus 8", "virus_id": "HPV91"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/AF531420", "text": "AF531420"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_004500", "text": "NC_004500"}, "notes": "null", "pave_id": "HPV92REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/12919731", "text": "Forslund et al., 2003"}, "species_name": "Betapapillomavirus 4", "virus_id": "HPV92"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/AY382778", "text": "AY382778"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV93REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/17412976", "text": "Vasiljevic et al., 2007"}, "species_name": "Betapapillomavirus 1", "virus_id": "HPV93"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/AJ620211", "text": "AJ620211"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV94REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/9359482", "text": "de Villiers et al., 1997"}, "species_name": "Alphapapillomavirus 2", "virus_id": "HPV94"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/AJ620210", "text": "AJ620210"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV95REF", "pave_name": "null", "reference": {"text": "Egawa et al, 2005"}, "species_name": "Gammapapillomavirus 1", "virus_id": "HPV95"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/AY382779", "text": "AY382779"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_005134", "text": "NC_005134"}, "notes": "null", "pave_id": "HPV96REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/17412976", "text": "Vasiljevic et al., 2007"}, "species_name": "Betapapillomavirus 5", "virus_id": "HPV96"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/DQ080080", "text": "DQ080080"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV97REF", "pave_name": "null", "reference": {"text": "Chen and Burk, 2007"}, "species_name": "Alphapapillomavirus 7", "virus_id": "HPV97"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/FM955837", "text": "FM955837"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV98REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/19386784", "text": "de Villiers et al., 2009"}, "species_name": "Betapapillomavirus 1", "virus_id": "HPV98"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/FM955838", "text": "FM955838"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV99REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/19386784", "text": "de Villiers et al., 2009"}, "species_name": "Betapapillomavirus 1", "virus_id": "HPV99"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/FM955839", "text": "FM955839"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV100REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/19386784", "text": "de Villiers et al., 2009"}, "species_name": "Betapapillomavirus 2", "virus_id": "HPV100"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/DQ080081", "text": "DQ080081"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_008189", "text": "NC_008189"}, "notes": "null", "pave_id": "HPV101REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/17125811", "text": "Chen et al., 2007"}, "species_name": "Gammapapillomavirus 6", "virus_id": "HPV101"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/DQ080083", "text": "DQ080083"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV102REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/16306621", "text": "Narechania et al., 2005"}, "species_name": "Alphapapillomavirus 3", "virus_id": "HPV102"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/DQ080078", "text": "DQ080078"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_008188", "text": "NC_008188"}, "notes": "null", "pave_id": "HPV103REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/17125811", "text": "Chen et al., 2007"}, "species_name": "Gammapapillomavirus 6", "virus_id": "HPV103"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/FM955840", "text": "FM955840"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV104REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/19386784", "text": "de Villiers et al., 2009"}, "species_name": "Betapapillomavirus 2", "virus_id": "HPV104"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/FM955841", "text": "FM955841"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV105REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/19386784", "text": "de Villiers et al., 2009"}, "species_name": "Betapapillomavirus 1", "virus_id": "HPV105"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/DQ080082", "text": "DQ080082"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV106REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/16306621", "text": "Narechania et al., 2005"}, "species_name": "Alphapapillomavirus 14", "virus_id": "HPV106"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/EF422221", "text": "EF422221"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV107REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/18796715", "text": "Vasiljevic et al., 2008"}, "species_name": "Betapapillomavirus 2", "virus_id": "HPV107"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/FM212639", "text": "FM212639"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_012213", "text": "NC_012213"}, "notes": "Revised", "pave_id": "HPV108REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/19153227", "text": "Nobre et al., 2009"}, "species_name": "Gammapapillomavirus 6", "virus_id": "HPV108"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/EU541441", "text": "EU541441"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_012485", "text": "NC_012485"}, "notes": "null", "pave_id": "HPV109REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/19969321", "text": "Ekstrom et al., 2010"}, "species_name": "Gammapapillomavirus 7", "virus_id": "HPV109"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/EU410348", "text": "EU410348"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV110REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/18796715", "text": "Vasiljevic et al., 2008"}, "species_name": "Betapapillomavirus 2", "virus_id": "HPV110"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/EU410349", "text": "EU410349"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Revised", "pave_id": "HPV111REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/18796715", "text": "Vasiljevic et al., 2008"}, "species_name": "Betapapillomavirus 2", "virus_id": "HPV111"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/EU541442", "text": "EU541442"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_012486", "text": "NC_012486"}, "notes": "null", "pave_id": "HPV112REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/19969321", "text": "Ekstrom et al., 2010"}, "species_name": "Gammapapillomavirus 8", "virus_id": "HPV112"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/FM955842", "text": "FM955842"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV113REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/19386784", "text": "de Villiers et al., 2009"}, "species_name": "Betapapillomavirus 2", "virus_id": "HPV113"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/GQ244463", "text": "GQ244463"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Revised", "pave_id": "HPV114REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/19969321", "text": "Ekstrom et al., 2010"}, "species_name": "Alphapapillomavirus 3", "virus_id": "HPV114"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/FJ947080", "text": "FJ947080"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV115REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/19948351", "text": "Chouhy et al., 2010"}, "species_name": "Betapapillomavirus 3", "virus_id": "HPV115"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/FJ804072", "text": "FJ804072"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_013035", "text": "NC_013035"}, "notes": "null", "pave_id": "HPV116REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/19570953", "text": "Li et al., 2009"}, "species_name": "Gammapapillomavirus 9", "virus_id": "HPV116"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/GQ246950", "text": "GQ246950"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV117REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/20096912", "text": "Kohler et al., 2010"}, "species_name": "Alphapapillomavirus 2", "virus_id": "HPV117"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/GQ246951", "text": "GQ246951"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV118REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/20206957", "text": "Bernard et al., 2010"}, "species_name": "Betapapillomavirus 1", "virus_id": "HPV118"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/GQ845441", "text": "GQ845441"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV119REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/20206957", "text": "Bernard et al., 2010"}, "species_name": "Gammapapillomavirus 8", "virus_id": "HPV119"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/GQ845442", "text": "GQ845442"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV120REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/20206957", "text": "Bernard et al., 2010"}, "species_name": "Betapapillomavirus 2", "virus_id": "HPV120"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/GQ845443", "text": "GQ845443"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_014185", "text": "NC_014185"}, "notes": "null", "pave_id": "HPV121REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/20206957", "text": "Bernard et al., 2010"}, "species_name": "Gammapapillomavirus 10", "virus_id": "HPV121"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/GQ845444", "text": "GQ845444"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV122REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/20206957", "text": "Bernard et al., 2010"}, "species_name": "Betapapillomavirus 2", "virus_id": "HPV122"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/GQ845445", "text": "GQ845445"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV123REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/20206957", "text": "Bernard et al., 2010"}, "species_name": "Gammapapillomavirus 7", "virus_id": "HPV123"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/GQ845446", "text": "GQ845446"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV124REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/20206957", "text": "Bernard et al., 2010"}, "species_name": "Betapapillomavirus 1", "virus_id": "HPV124"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/FN547152", "text": "FN547152"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV125REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/21811601", "text": "Kovanda et al., 2011"}, "species_name": "Alphapapillomavirus 2", "virus_id": "HPV125"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/AB646346", "text": "AB646346"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_016157", "text": "NC_016157"}, "notes": "null", "pave_id": "HPV126REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/22056388", "text": "Egawa et al, 2012"}, "species_name": "Gammapapillomavirus 11", "virus_id": "HPV126"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/HM011570", "text": "HM011570"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_014469", "text": "NC_014469"}, "notes": "null", "pave_id": "HPV127REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/20542254", "text": "Schowalter et al., 2010"}, "species_name": "Gammapapillomavirus 12", "virus_id": "HPV127"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/GU225708", "text": "GU225708"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_014952", "text": "NC_014952"}, "notes": "null", "pave_id": "HPV128REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/21471318/", "text": "Kohler et al, 2011"}, "species_name": "Gammapapillomavirus 13", "virus_id": "HPV128"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/GU233853", "text": "GU233853"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_014953", "text": "NC_014953"}, "notes": "null", "pave_id": "HPV129REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/21471318/", "text": "Kohler et al, 2011"}, "species_name": "Gammapapillomavirus 9", "virus_id": "HPV129"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/GU117630", "text": "GU117630"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV130REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/21471318/", "text": "Kohler et al, 2011"}, "species_name": "Gammapapillomavirus 10", "virus_id": "HPV130"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/GU117631", "text": "GU117631"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_014954", "text": "NC_014954"}, "notes": "null", "pave_id": "HPV131REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/21471318/", "text": "Kohler et al, 2011"}, "species_name": "Gammapapillomavirus 14", "virus_id": "HPV131"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/GU117632", "text": "GU117632"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_014955", "text": "NC_014955"}, "notes": "null", "pave_id": "HPV132REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/21471318/", "text": "Kohler et al, 2011"}, "species_name": "Gammapapillomavirus 12", "virus_id": "HPV132"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/GU117633", "text": "GU117633"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV133REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/21471318/", "text": "Kohler et al, 2011"}, "species_name": "Gammapapillomavirus 10", "virus_id": "HPV133"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/GU117634", "text": "GU117634"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_014956", "text": "NC_014956"}, "notes": "null", "pave_id": "HPV134REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/21471318/", "text": "Kohler et al, 2011"}, "species_name": "Gammapapillomavirus 7", "virus_id": "HPV134"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/HM999987", "text": "HM999987"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_017993", "text": "NC_017993"}, "notes": "null", "pave_id": "HPV135REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/21844305", "text": "Bottalico et al., 2011"}, "species_name": "Gammapapillomavirus 15", "virus_id": "HPV135"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/HM999988", "text": "HM999988"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_017994", "text": "NC_017994"}, "notes": "null", "pave_id": "HPV136REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/21844305", "text": "Bottalico et al., 2011"}, "species_name": "Gammapapillomavirus 11", "virus_id": "HPV136"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/HM999989", "text": "HM999989"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_017995", "text": "NC_017995"}, "notes": "null", "pave_id": "HPV137REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/21844305", "text": "Bottalico et al., 2011"}, "species_name": "Gammapapillomavirus 16", "virus_id": "HPV137"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/HM999990", "text": "HM999990"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV138REF", "pave_name": "null", "reference": {"text": "Chen et al., Unpublished"}, "species_name": "Gammapapillomavirus 7", "virus_id": "HPV138"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/HM999991", "text": "HM999991"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV139REF", "pave_name": "null", "reference": {"text": "Chen et al., Unpublished"}, "species_name": "Gammapapillomavirus 7", "virus_id": "HPV139"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/HM999992", "text": "HM999992"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_017996", "text": "NC_017996"}, "notes": "null", "pave_id": "HPV140REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/21844305", "text": "Bottalico et al., 2011"}, "species_name": "Gammapapillomavirus 11", "virus_id": "HPV140"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/HM999993", "text": "HM999993"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV141REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/21844305", "text": "Bottalico et al., 2011"}, "species_name": "Gammapapillomavirus 11", "virus_id": "HPV141"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/HM999994", "text": "HM999994"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV142REF", "pave_name": "null", "reference": {"text": "Chen et al., Unpublished"}, "species_name": "Gammapapillomavirus 10", "virus_id": "HPV142"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/HM999995", "text": "HM999995"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV143REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/21844305", "text": "Bottalico et al., 2011"}, "species_name": "Betapapillomavirus 1", "virus_id": "HPV143"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/HM999996", "text": "HM999996"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_017997", "text": "NC_017997"}, "notes": "null", "pave_id": "HPV144REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/21844305", "text": "Bottalico et al., 2011"}, "species_name": "Gammapapillomavirus 17", "virus_id": "HPV144"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/HM999997", "text": "HM999997"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV145REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/21844305", "text": "Bottalico et al., 2011"}, "species_name": "Betapapillomavirus 2", "virus_id": "HPV145"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/HM999998", "text": "HM999998"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV146REF", "pave_name": "null", "reference": {"text": "Chen et al., Unpublished"}, "species_name": "Gammapapillomavirus 15", "virus_id": "HPV146"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/HM999999", "text": "HM999999"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV147REF", "pave_name": "null", "reference": {"text": "Chen et al., Unpublished"}, "species_name": "Gammapapillomavirus 8", "virus_id": "HPV147"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/GU129016", "text": "GU129016"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV148REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/21471318/", "text": "Kohler et al, 2011"}, "species_name": "Gammapapillomavirus 12", "virus_id": "HPV148"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/GU117629", "text": "GU117629"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV149REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/21471318/", "text": "Kohler et al, 2011"}, "species_name": "Gammapapillomavirus 7", "virus_id": "HPV149"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/FN677755", "text": "FN677755"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV150REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/15737917", "text": "Kovanda et al, 2011"}, "species_name": "Betapapillomavirus 5", "virus_id": "HPV150"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/FN677756", "text": "FN677756"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV151REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/15737917", "text": "Kovanda et al, 2011"}, "species_name": "Betapapillomavirus 2", "virus_id": "HPV151"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/JF304768", "text": "JF304768"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV152REF", "pave_name": "null", "reference": {"text": "Chen et al., Unpublished"}, "species_name": "Betapapillomavirus 1", "virus_id": "HPV152"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/JN171845", "text": "JN171845"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV153REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/23324975/", "text": "Sturegard et al, 2013"}, "species_name": "Gammapapillomavirus 13", "virus_id": "HPV153"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/JN211193", "text": "JN211193"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_021483", "text": "NC_021483"}, "notes": "null", "pave_id": "HPV154REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/24551244/", "text": "Ure and Forslund, 2014"}, "species_name": "Gammapapillomavirus 11", "virus_id": "HPV154"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/JF906559", "text": "JF906559"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV155REF", "pave_name": "null", "reference": {"text": "Bzhalava et al, 2013"}, "species_name": "Gammapapillomavirus 7", "virus_id": "HPV155"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/JX429973", "text": "JX429973"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV156REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/23136368", "text": "Chouhy et al, 2013"}, "species_name": "Gammapapillomavirus 18", "virus_id": "HPV156"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KT698166", "text": "KT698166"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Classification Pending Approval by the ICTV", "pave_id": "HPV157REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/27108808/", "text": "Bolatti et al, 2016"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV157"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KT698168", "text": "KT698168"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Classification Pending Approval by the ICTV", "pave_id": "HPV158REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/27108808/", "text": "Bolatti et al, 2016"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV158"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/HE963025", "text": "HE963025"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV159REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/23723399", "text": "Kocjan et al, 2013"}, "species_name": "Betapapillomavirus 2", "virus_id": "HPV159"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/AB745694", "text": "AB745694"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV160REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/24282509/", "text": "Mitsuishi et al, 2013"}, "species_name": "Alphapapillomavirus 2", "virus_id": "HPV160"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/JX413109", "text": "JX413109"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV161REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/23043169", "text": "Li et al., 2012"}, "species_name": "Gammapapillomavirus 19", "virus_id": "HPV161"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/JX413108", "text": "JX413108"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV162REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/23043169", "text": "Li et al., 2012"}, "species_name": "Gammapapillomavirus 19", "virus_id": "HPV162"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/JX413107", "text": "JX413107"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV163REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/23043169", "text": "Li et al., 2012"}, "species_name": "Gammapapillomavirus 20", "virus_id": "HPV163"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/JX413106", "text": "JX413106"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV164REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/23043169", "text": "Li et al., 2012"}, "species_name": "Gammapapillomavirus 8", "virus_id": "HPV164"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/JX444072", "text": "JX444072"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Revised", "pave_id": "HPV165REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/23043169", "text": "Li et al., 2012"}, "species_name": "Gammapapillomavirus 12", "virus_id": "HPV165"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/JX413104", "text": "JX413104"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_019023", "text": "NC_019023"}, "notes": "null", "pave_id": "HPV166REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/23043169", "text": "Li et al., 2012"}, "species_name": "Gammapapillomavirus 19", "virus_id": "HPV166"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KC862318", "text": "KC862318"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_022892", "text": "NC_022892"}, "notes": "null", "pave_id": "HPV167REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/24155922", "text": "Li et al., 2013"}, "species_name": "Gammapapillomavirus 21", "virus_id": "HPV167"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KC862317", "text": "KC862317"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV168REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/24155922", "text": "Li et al., 2013"}, "species_name": "Gammapapillomavirus 8", "virus_id": "HPV168"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/JX413105", "text": "JX413105"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV169REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/23043169", "text": "Li et al., 2012"}, "species_name": "Gammapapillomavirus 11", "virus_id": "HPV169"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/JX413110", "text": "JX413110"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV170REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/23043169", "text": "Li et al., 2012"}, "species_name": "Gammapapillomavirus 7", "virus_id": "HPV170"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KF006398", "text": "KF006398"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV171REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/24268765/", "text": "Martin et al, 2013"}, "species_name": "Gammapapillomavirus 11", "virus_id": "HPV171"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KF006399", "text": "KF006399"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV172REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/24268765/", "text": "Martin et al, 2013"}, "species_name": "Gammapapillomavirus 22", "virus_id": "HPV172"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KF006400", "text": "KF006400"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV173REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/24268765/", "text": "Martin et al, 2013"}, "species_name": "Gammapapillomavirus 1", "virus_id": "HPV173"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/HF930491", "text": "HF930491"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV174REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/23723399", "text": "Kocjan et al, 2013"}, "species_name": "Betapapillomavirus 2", "virus_id": "HPV174"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KC108721", "text": "KC108721"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV175REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/23522725", "text": "Johansson et al., 2013"}, "species_name": "Gammapapillomavirus 23", "virus_id": "HPV175"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KR816167", "text": "KR816167"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV176REF", "pave_name": "null", "reference": {"text": "Chen et al., Unpublished"}, "species_name": "Gammapapillomavirus 8", "virus_id": "HPV176"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KR816168", "text": "KR816168"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV177REF", "pave_name": "null", "reference": {"text": "Chen et al., Unpublished"}, "species_name": "Alphapapillomavirus 7", "virus_id": "HPV177"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KJ130020", "text": "KJ130020"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_023891", "text": "NC_023891"}, "notes": "null", "pave_id": "HPV178REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/24855297", "text": "Johansson and Forslund, 2014"}, "species_name": "Gammapapillomavirus 24", "virus_id": "HPV178"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/HG421739", "text": "HG421739"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_022095", "text": "NC_022095"}, "notes": "null", "pave_id": "HPV179REF", "pave_name": "null", "reference": {"text": "Hosnjak et al, 2015"}, "species_name": "Gammapapillomavirus 15", "virus_id": "HPV179"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KC108722", "text": "KC108722"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV180REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/23522725", "text": "Johansson et al., 2013"}, "species_name": "Gammapapillomavirus 10", "virus_id": "HPV180"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KR816169", "text": "KR816169"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV181REF", "pave_name": "null", "reference": {"text": "Chen et al., Unpublished"}, "species_name": "Gammapapillomavirus 11", "virus_id": "HPV181"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KR816170", "text": "KR816170"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV182REF", "pave_name": "null", "reference": {"text": "Chen et al., Unpublished"}, "species_name": "Betapapillomavirus 2", "virus_id": "HPV182"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KR816171", "text": "KR816171"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV183REF", "pave_name": "null", "reference": {"text": "Chen et al., Unpublished"}, "species_name": "Gammapapillomavirus 20", "virus_id": "HPV183"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/HG530535", "text": "HG530535"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV184REF", "pave_name": "null", "reference": {"text": "Hosnjak et al, 2015"}, "species_name": "Gammapapillomavirus 25", "virus_id": "HPV184"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KR816172", "text": "KR816172"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV185REF", "pave_name": "null", "reference": {"text": "Chen et al., Unpublished"}, "species_name": "Betapapillomavirus 5", "virus_id": "HPV185"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KR816173", "text": "KR816173"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV186REF", "pave_name": "null", "reference": {"text": "Chen et al., Unpublished"}, "species_name": "Gammapapillomavirus 7", "virus_id": "HPV186"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KR816174", "text": "KR816174"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV187REF", "pave_name": "null", "reference": {"text": "Chen et al., Unpublished"}, "species_name": "Gammapapillomavirus 26", "virus_id": "HPV187"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KR816175", "text": "KR816175"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV188REF", "pave_name": "null", "reference": {"text": "Chen et al., Unpublished"}, "species_name": "Gammapapillomavirus 3", "virus_id": "HPV188"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KR816176", "text": "KR816176"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV189REF", "pave_name": "null", "reference": {"text": "Chen et al., Unpublished"}, "species_name": "Gammapapillomavirus 7", "virus_id": "HPV189"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KR816177", "text": "KR816177"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV190REF", "pave_name": "null", "reference": {"text": "Chen et al., Unpublished"}, "species_name": "Gammapapillomavirus 24", "virus_id": "HPV190"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KR816178", "text": "KR816178"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV191REF", "pave_name": "null", "reference": {"text": "Chen et al., Unpublished"}, "species_name": "Gammapapillomavirus 10", "virus_id": "HPV191"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KR816179", "text": "KR816179"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV192REF", "pave_name": "null", "reference": {"text": "Chen et al., Unpublished"}, "species_name": "Gammapapillomavirus 15", "virus_id": "HPV192"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KR816180", "text": "KR816180"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV193REF", "pave_name": "null", "reference": {"text": "Chen et al., Unpublished"}, "species_name": "Gammapapillomavirus 7", "virus_id": "HPV193"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KR816181", "text": "KR816181"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV194REF", "pave_name": "null", "reference": {"text": "Chen et al., Unpublished"}, "species_name": "Gammapapillomavirus 20", "virus_id": "HPV194"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KR816182", "text": "KR816182"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV195REF", "pave_name": "null", "reference": {"text": "Chen et al., Unpublished"}, "species_name": "Betapapillomavirus 1", "virus_id": "HPV195"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KR816183", "text": "KR816183"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV196REF", "pave_name": "null", "reference": {"text": "Chen et al., Unpublished"}, "species_name": "Betapapillomavirus 1", "virus_id": "HPV196"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KM085343", "text": "KM085343"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV197REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/25388227/", "text": "Arroyo et al., 2014"}, "species_name": "Gammapapillomavirus 24", "virus_id": "HPV197"}, {"abbreviation": "null", "genbank": "null", "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV198REF", "pave_name": "null", "reference": {"text": "Arroyo et al., Unpublished"}, "species_name": "Betapapillomavirus 2", "virus_id": "HPV198"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KJ913662", "text": "KJ913662"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV199REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/26375679/", "text": "Ostbrenk et al., 2015"}, "species_name": "Gammapapillomavirus 12", "virus_id": "HPV199"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KP692114", "text": "KP692114"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV200REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/26318260/", "text": "Arroyo et al., 2015"}, "species_name": "Gammapapillomavirus 2", "virus_id": "HPV200"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KP692115", "text": "KP692115"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_027528", "text": "NC_027528"}, "notes": "null", "pave_id": "HPV201REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/26318260/", "text": "Arroyo et al., 2015"}, "species_name": "Gammapapillomavirus 27", "virus_id": "HPV201"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KP692116", "text": "KP692116"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV202REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/26318260/", "text": "Arroyo et al., 2015"}, "species_name": "Gammapapillomavirus 11", "virus_id": "HPV202"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MG921180", "text": "MG921180"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV203REF", "pave_name": "null", "reference": {"text": "Arroyo et al., Unpublished"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV203"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KP769769", "text": "KP769769"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "HPV204REF", "pave_name": "null", "reference": {"text": "Kocjan et al, 2015"}, "species_name": "Mupapillomavirus 3", "virus_id": "HPV204"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KT698167", "text": "KT698167"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Classification Pending Approval by the ICTV", "pave_id": "HPV205REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/27108808/", "text": "Bolatti et al, 2016"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV205"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/U85660", "text": "U85660"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Classification Pending Approval by the ICTV", "pave_id": "HPV206REF", "pave_name": "null", "reference": {"link": "https://www.ncbi.nlm.nih.gov/pubmed/8980287", "text": "Hopfl et al., 1997"}, "species_name": "Betapapillomavirus", "virus_id": "HPV206"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MK645900", "text": "MK645900"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Classification Pending Approval by the ICTV", "pave_id": "HPV207REF", "pave_name": "null", "reference": {"text": "Parras-Molto and Lopez-Bueno, Unpublished"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV207"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MK645901", "text": "MK645901"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Classification Pending Approval by the ICTV", "pave_id": "HPV208REF", "pave_name": "null", "reference": {"text": "Parras-Molto and Lopez-Bueno, Unpublished"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV208"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KY242583", "text": "KY242583"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Classification Pending Approval by the ICTV", "pave_id": "HPV209REF", "pave_name": "null", "reference": {"link": "https://www.ncbi.nlm.nih.gov/pubmed/28590241", "text": "Bolatti et al., 2017"}, "species_name": "Betapapillomavirus", "virus_id": "HPV209"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH460956", "text": "MH460956"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Classification Pending Approval by the ICTV", "pave_id": "HPV210REF", "pave_name": "null", "reference": {"link": "https://www.ncbi.nlm.nih.gov/pubmed/30292127", "text": "Bolatti et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV210"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF509816", "text": "MF509816"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Classification Pending Approval by the ICTV", "pave_id": "HPV211REF", "pave_name": "null", "reference": {"text": "Murahwa et al, 2019"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV211"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF509817", "text": "MF509817"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Classification Pending Approval by the ICTV", "pave_id": "HPV212REF", "pave_name": "null", "reference": {"text": "Murahwa et al, 2019"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV212"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF509818", "text": "MF509818"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Classification Pending Approval by the ICTV", "pave_id": "HPV213REF", "pave_name": "null", "reference": {"text": "Murahwa et al, 2019"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV213"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF509819", "text": "MF509819"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Classification Pending Approval by the ICTV", "pave_id": "HPV214REF", "pave_name": "null", "reference": {"text": "Murahwa et al, 2019"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV214"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF509820", "text": "MF509820"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Classification Pending Approval by the ICTV", "pave_id": "HPV215REF", "pave_name": "null", "reference": {"text": "Murahwa et al, 2019"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV215"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF509821", "text": "MF509821"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Classification Pending Approval by the ICTV", "pave_id": "HPV216REF", "pave_name": "null", "reference": {"text": "Murahwa et al, 2019"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV216"}, {"abbreviation": "null", "genbank": "null", "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "null", "pave_name": "null", "reference": "null", "species_name": "Variant of HPV182", "virus_id": "HPV217"}, {"abbreviation": "null", "genbank": "null", "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "null", "pave_id": "null", "pave_name": "null", "reference": "null", "species_name": "Variant of HPV189", "virus_id": "HPV218"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH172376", "text": "MH172376"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Classification Pending Approval by the ICTV", "pave_id": "HPV219REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/29930074/", "text": "Murahwa et al, 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV219"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH172377", "text": "MH172377"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Classification Pending Approval by the ICTV", "pave_id": "HPV220REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/29930074/", "text": "Murahwa et al, 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV220"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH172378", "text": "MH172378"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Classification Pending Approval by the ICTV", "pave_id": "HPV221REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/29930074/", "text": "Murahwa et al, 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV221"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH172379", "text": "MH172379"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Classification Pending Approval by the ICTV", "pave_id": "HPV222REF", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/29930074/", "text": "Murahwa et al, 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV222"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MG063749", "text": "MG063749"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Classification Pending Approval by the ICTV", "pave_id": "HPV223REF", "pave_name": "null", "reference": {"text": "Dutta et al., Unpublished"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV223"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF356498", "text": "MF356498"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Classification Pending Approval by the ICTV", "pave_id": "HPV224REF", "pave_name": "null", "reference": {"link": "https://www.ncbi.nlm.nih.gov/pubmed/28839025", "text": "Brancaccio et al., 2017"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV224"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MG520499", "text": "MG520499"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Classification Pending Approval by the ICTV", "pave_id": "HPV225REF", "pave_name": "null", "reference": {"text": "Dutta et al., Unpublished"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV225"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MG813996", "text": "MG813996"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Classification Pending Approval by the ICTV", "pave_id": "HPV226REF", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/29545294", "text": "Latsuzbaia et al, 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV226"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MK080568", "text": "MK080568"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Classification Pending Approval by the ICTV", "pave_id": "HPV227REF", "pave_name": "null", "reference": {"text": "Brancaccio et al., Unpublished"}, "species_name": "Betapapillomavirus", "virus_id": "HPV227"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/JF966378", "text": "JF966378"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mCG2nr", "pave_name": "null", "reference": {"text": "Sauvage et al., Unpublished"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mCG2"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/JF966379", "text": "JF966379"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mCG3nr", "pave_name": "null", "reference": {"text": "Sauvage et al., Unpublished"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mCG3"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MG869605", "text": "MG869605"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mCGG5nr", "pave_name": "null", "reference": {"text": "Mollerup et al, Unpublished"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mCGG5"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KF791917", "text": "KF791917"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mCH2nr", "pave_name": "null", "reference": {"text": "Yu et al., Unpublished"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mCH2"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KX781280", "text": "KX781280"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mDysk1nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/28040372", "text": "Nguyen et al., 2016"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mDysk1"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KX781281", "text": "KX781281"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mDysk2nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/28040372", "text": "Nguyen et al., 2016"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mDysk2"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KX781282", "text": "KX781282"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mDysk3nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/28040372", "text": "Nguyen et al., 2016"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mDysk3"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KX781284", "text": "KX781284"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mDysk5nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/28040372", "text": "Nguyen et al., 2016"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mDysk5"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KX781285", "text": "KX781285"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mDysk6nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/28040372", "text": "Nguyen et al., 2016"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mDysk6"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588698", "text": "MF588698"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mEV03c05nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mEV03c05"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588687", "text": "MF588687"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mEV03c09nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Betapapillomavirus", "virus_id": "HPV-mEV03c09"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588746", "text": "MF588746"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mEV03c40nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mEV03c40"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588721", "text": "MF588721"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mEV03c45nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mEV03c45"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588724", "text": "MF588724"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mEV03c104nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mEV03c104"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588729", "text": "MF588729"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mEV03c188nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mEV03c188"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588735", "text": "MF588735"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mEV03c212nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mEV03c212"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588755", "text": "MF588755"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mEV03c434nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mEV03c434"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588676", "text": "MF588676"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mEV06c12bnr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Alphapapillomavirus", "virus_id": "HPV-mEV06c12b"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588747", "text": "MF588747"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mEV06c107nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mEV06c107"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588736", "text": "MF588736"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mEV06c118nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mEV06c118"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588716", "text": "MF588716"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mEV07c367nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mEV07c367"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588723", "text": "MF588723"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mEV07c382nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mEV07c382"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588705", "text": "MF588705"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mEV07c390nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mEV07c390"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/JF966375", "text": "JF966375"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mFD1nr", "pave_name": "null", "reference": {"text": "Sauvage et al., Unpublished"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mFD1"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/JF966376", "text": "JF966376"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mFD2nr", "pave_name": "null", "reference": {"text": "Sauvage et al., Unpublished"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mFD2"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/JF966373", "text": "JF966373"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mFS1nr", "pave_name": "null", "reference": {"text": "Sauvage et al., Unpublished"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mFS1"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KC311731", "text": "KC311731"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mFi864nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/23516180", "text": "Phan et al., 2013"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mFi864"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588677", "text": "MF588677"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mHIVGc36nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Betapapillomavirus", "virus_id": "HPV-mHIVGc36"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/JX444073", "text": "JX444073"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mKC5nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/23043169", "text": "Li et al., 2012"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mKC5"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/JF966371", "text": "JF966371"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mKN1nr", "pave_name": "null", "reference": {"text": "Sauvage et al., Unpublished"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mKN1"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/JF966372", "text": "JF966372"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mKN2nr", "pave_name": "null", "reference": {"text": "Sauvage et al., Unpublished"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mKN2"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/JF966374", "text": "JF966374"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mKN3nr", "pave_name": "null", "reference": {"text": "Sauvage et al., Unpublished"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mKN3"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KF482069", "text": "KF482069"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mL55nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/24092778", "text": "Yu et al., 2013"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mL55"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588688", "text": "MF588688"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mLCOSOc196nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mLCOSOc196"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KC113191", "text": "KC113191"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSD2nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/23554892", "text": "Mokili et al., 2013"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSD2"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KP692117", "text": "KP692117"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_027779", "text": "NC_027779"}, "notes": "Revised", "pave_id": "HPV-mSE379nr", "pave_name": "null", "reference": {"text": "Arroyo et al., Unpublished"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSE379"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KP692118", "text": "KP692118"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSE383nr", "pave_name": "null", "reference": {"text": "Arroyo et al., Unpublished"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSE383"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH675888", "text": "MH675888"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK001nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK001"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777156", "text": "MH777156"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK008nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK008"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777158", "text": "MH777158"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK010nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK010"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777159", "text": "MH777159"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK011nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK011"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777160", "text": "MH777160"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK012nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK012"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777161", "text": "MH777161"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK013nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK013"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777162", "text": "MH777162"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK014nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK014"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777163", "text": "MH777163"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK015nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK015"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777167", "text": "MH777167"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK019nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK019"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777168", "text": "MH777168"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK020nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK020"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777170", "text": "MH777170"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK022nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK022"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777171", "text": "MH777171"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK023nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK023"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777173", "text": "MH777173"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK025nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Mupapillomavirus", "virus_id": "HPV-mSK025"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777175", "text": "MH777175"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK027nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Betapapillomavirus", "virus_id": "HPV-mSK027"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777176", "text": "MH777176"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK028nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK028"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777177", "text": "MH777177"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK029nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK029"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777178", "text": "MH777178"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK030nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK030"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777182", "text": "MH777182"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK034nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK034"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777185", "text": "MH777185"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK037nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK037"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777186", "text": "MH777186"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK038nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK038"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777187", "text": "MH777187"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK039nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK039"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH972557", "text": "MH972557"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK040nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK040"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777188", "text": "MH777188"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK041nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK041"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777190", "text": "MH777190"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK043nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Betapapillomavirus", "virus_id": "HPV-mSK043"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH972558", "text": "MH972558"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK045nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK045"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777192", "text": "MH777192"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK046nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK046"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777194", "text": "MH777194"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK049nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK049"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777195", "text": "MH777195"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK050nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK050"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777196", "text": "MH777196"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK051nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK051"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777199", "text": "MH777199"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK054nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK054"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777200", "text": "MH777200"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK055nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK055"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777201", "text": "MH777201"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK056nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK056"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777202", "text": "MH777202"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK057nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK057"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777203", "text": "MH777203"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK058nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK058"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777206", "text": "MH777206"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK061nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK061"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777207", "text": "MH777207"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK062nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK062"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777208", "text": "MH777208"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK063nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK063"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777209", "text": "MH777209"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK064nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK064"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777210", "text": "MH777210"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK065nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK065"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777212", "text": "MH777212"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK067nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK067"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777219", "text": "MH777219"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK075nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK075"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777220", "text": "MH777220"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK076nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK076"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777222", "text": "MH777222"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK078nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK078"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH972561", "text": "MH972561"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK081nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK081"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777226", "text": "MH777226"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK083nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK083"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777228", "text": "MH777228"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK085nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK085"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777229", "text": "MH777229"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK086nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK086"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777230", "text": "MH777230"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK087nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK087"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777232", "text": "MH777232"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK089nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK089"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777233", "text": "MH777233"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK090nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK090"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777234", "text": "MH777234"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK091nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK091"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777236", "text": "MH777236"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK093nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK093"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777237", "text": "MH777237"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK094nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK094"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777238", "text": "MH777238"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK095nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK095"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777239", "text": "MH777239"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK096nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK096"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777241", "text": "MH777241"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK098nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK098"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777243", "text": "MH777243"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK100nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK100"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH972562", "text": "MH972562"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK101nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK101"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777244", "text": "MH777244"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK102nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK102"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777245", "text": "MH777245"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK103nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK103"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777249", "text": "MH777249"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK107nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK107"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777251", "text": "MH777251"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK109nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK109"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777253", "text": "MH777253"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK111nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Betapapillomavirus", "virus_id": "HPV-mSK111"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777257", "text": "MH777257"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK115nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK115"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777258", "text": "MH777258"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK116nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK116"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777259", "text": "MH777259"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK117nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK117"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777260", "text": "MH777260"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK118nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK118"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777261", "text": "MH777261"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK119nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK119"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777262", "text": "MH777262"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK120nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK120"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777263", "text": "MH777263"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK121nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK121"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777268", "text": "MH777268"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK126nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK126"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777270", "text": "MH777270"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK128nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK128"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777273", "text": "MH777273"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK131nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK131"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777274", "text": "MH777274"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK132nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK132"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777280", "text": "MH777280"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK138nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK138"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777281", "text": "MH777281"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK139nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK139"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777288", "text": "MH777288"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK146nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK146"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777289", "text": "MH777289"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK147nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK147"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777292", "text": "MH777292"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK150nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK150"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777294", "text": "MH777294"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK152nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK152"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777297", "text": "MH777297"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK155nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK155"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777298", "text": "MH777298"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK156nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK156"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777302", "text": "MH777302"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK160nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK160"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777306", "text": "MH777306"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK164nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Betapapillomavirus", "virus_id": "HPV-mSK164"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777307", "text": "MH777307"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK165nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK165"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777308", "text": "MH777308"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK166nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK166"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777309", "text": "MH777309"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK167nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK167"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777310", "text": "MH777310"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK168nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK168"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777311", "text": "MH777311"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK169nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK169"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777312", "text": "MH777312"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK170nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK170"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777313", "text": "MH777313"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK171nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK171"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777315", "text": "MH777315"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK173nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK173"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777316", "text": "MH777316"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK174nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK174"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777318", "text": "MH777318"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK176nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK176"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777325", "text": "MH777325"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK183nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK183"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777327", "text": "MH777327"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK185nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK185"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777328", "text": "MH777328"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK186nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK186"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777331", "text": "MH777331"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK189nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK189"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777332", "text": "MH777332"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK190nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK190"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777333", "text": "MH777333"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK191nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK191"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777334", "text": "MH777334"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK192nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK192"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777339", "text": "MH777339"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK197nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK197"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH972563", "text": "MH972563"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK199nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK199"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777343", "text": "MH777343"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK202nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK202"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777345", "text": "MH777345"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK204nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK204"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777346", "text": "MH777346"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK205nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK205"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777347", "text": "MH777347"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK206nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK206"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777350", "text": "MH777350"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK209nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Betapapillomavirus", "virus_id": "HPV-mSK209"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777351", "text": "MH777351"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK210nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK210"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777352", "text": "MH777352"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK211nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK211"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777355", "text": "MH777355"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK216nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK216"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777356", "text": "MH777356"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK217nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK217"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777357", "text": "MH777357"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK218nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK218"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777358", "text": "MH777358"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK219nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Betapapillomavirus", "virus_id": "HPV-mSK219"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777366", "text": "MH777366"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK227nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK227"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777368", "text": "MH777368"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK229nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK229"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777370", "text": "MH777370"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK231nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK231"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777377", "text": "MH777377"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK238nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK238"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777378", "text": "MH777378"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK239nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK239"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777379", "text": "MH777379"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK240nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK240"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777380", "text": "MH777380"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK241nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK241"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777381", "text": "MH777381"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK242nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK242"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777383", "text": "MH777383"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK244nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK244"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777384", "text": "MH777384"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK245nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK245"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777385", "text": "MH777385"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK246nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK246"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777388", "text": "MH777388"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK249nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK249"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MH777389", "text": "MH777389"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mSK250nr", "pave_name": "null", "reference": {"link": "https://pubmed.ncbi.nlm.nih.gov/30397357/", "text": "Tirosh et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mSK250"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF176072", "text": "MF176072"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mTG550nr", "pave_name": "null", "reference": {"text": "Chen et al., Unpublished"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mTG550"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588684", "text": "MF588684"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mTVMBSFc09nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Betapapillomavirus", "virus_id": "HPV-mTVMBSFc09"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588706", "text": "MF588706"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mTVMBSGc529nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mTVMBSGc529"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588686", "text": "MF588686"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mTVMBSGc2024nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Betapapillomavirus", "virus_id": "HPV-mTVMBSGc2024"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588732", "text": "MF588732"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mTVMBSGc2450nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mTVMBSGc2450"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588738", "text": "MF588738"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mTVMBSHc13nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mTVMBSHc13"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588707", "text": "MF588707"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mTVMBSHc33nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mTVMBSHc33"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588739", "text": "MF588739"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mTVMBSWc141nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mTVMBSWc141"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/KX082661", "text": "KX082661"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mZJ01nr", "pave_name": "null", "reference": {"text": "Liu and Zhang, Unpublished"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mZJ01"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588757", "text": "MF588757"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-md01c06nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Mupapillomavirus", "virus_id": "HPV-md01c06"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588734", "text": "MF588734"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mdo1c02nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mdo1c02"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588704", "text": "MF588704"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mdo1c232nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mdo1c232"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588744", "text": "MF588744"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mga2c01nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mga2c01"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588754", "text": "MF588754"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mga2c70nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mga2c70"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588681", "text": "MF588681"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mm090c09nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Betapapillomavirus", "virus_id": "HPV-mm090c09"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588745", "text": "MF588745"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mm090c10nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mm090c10"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588748", "text": "MF588748"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mm090c66nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mm090c66"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588737", "text": "MF588737"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mm090c145nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mm090c145"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588682", "text": "MF588682"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mm292c14nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Betapapillomavirus", "virus_id": "HPV-mm292c14"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588683", "text": "MF588683"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mm292c88nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Betapapillomavirus", "virus_id": "HPV-mm292c88"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588685", "text": "MF588685"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mm292c100nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Betapapillomavirus", "virus_id": "HPV-mm292c100"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588696", "text": "MF588696"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw02c24anr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw02c24a"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588753", "text": "MF588753"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw07c34dnr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw07c34d"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588717", "text": "MF588717"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw07c68bnr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw07c68b"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588709", "text": "MF588709"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw11C24nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw11C24"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588710", "text": "MF588710"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw11C39nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw11C39"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588689", "text": "MF588689"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw11C51nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw11C51"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588718", "text": "MF588718"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw11c13nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw11c13"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588740", "text": "MF588740"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw18c07nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw18c07"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588733", "text": "MF588733"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw18c11dnr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw18c11d"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588714", "text": "MF588714"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw18c25nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw18c25"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588741", "text": "MF588741"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw18c39nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw18c39"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588725", "text": "MF588725"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw18c134nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw18c134"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588701", "text": "MF588701"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw20c01anr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw20c01a"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588708", "text": "MF588708"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw20c01bnr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw20c01b"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588702", "text": "MF588702"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw20c02cnr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw20c02c"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588715", "text": "MF588715"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw20c03anr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw20c03a"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588695", "text": "MF588695"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw20c04nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw20c04"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588742", "text": "MF588742"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw20c08anr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw20c08a"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588703", "text": "MF588703"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw20c09nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw20c09"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588726", "text": "MF588726"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw20c10anr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw20c10a"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588743", "text": "MF588743"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw21c693nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw21c693"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588750", "text": "MF588750"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw22c09nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw22c09"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588690", "text": "MF588690"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw23c08cnr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw23c08c"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588719", "text": "MF588719"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw23c77nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw23c77"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588711", "text": "MF588711"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw23c101cnr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw23c101c"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588758", "text": "MF588758"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw27c03anr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw27c03a"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588728", "text": "MF588728"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw27c04cnr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw27c04c"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588712", "text": "MF588712"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw27c39cnr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw27c39c"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588692", "text": "MF588692"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw27c157cnr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw27c157c"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588693", "text": "MF588693"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw34c04anr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw34c04a"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588720", "text": "MF588720"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw34c11anr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw34c11a"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588694", "text": "MF588694"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw34c14anr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw34c14a"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588751", "text": "MF588751"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw34c28anr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw34c28a"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588731", "text": "MF588731"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mw34c34anr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mw34c34a"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588756", "text": "MF588756"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mwg1c05nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mwg1c05"}, {"abbreviation": "null", "genbank": {"link": "https://www.ncbi.nlm.nih.gov/nuccore/MF588727", "text": "MF588727"}, "host_common_name": "Human", "host_scientific_name": "Homo sapiens", "ncbi_refseq": "null", "notes": "Not classified by HPV Reference Center", "pave_id": "HPV-mwg1c09nr", "pave_name": "null", "reference": {"link": "http://www.ncbi.nlm.nih.gov/pubmed/30541782", "text": "Pastrana et al., 2018"}, "species_name": "Gammapapillomavirus", "virus_id": "HPV-mwg1c09"}];

# %%
dict[0]
# Out:
# {'abbreviation': 'null',
#  'genbank': {'link': 'https://www.ncbi.nlm.nih.gov/nuccore/V01116',
#   'text': 'V01116'},
#  'host_common_name': 'Human',
#  'host_scientific_name': 'Homo sapiens',
#  'ncbi_refseq': 'null',
#  'notes': 'Revised',
#  'pave_id': 'HPV1REF',
#  'pave_name': 'null',
#  'reference': {'link': 'http://www.ncbi.nlm.nih.gov/pubmed/6281972',
#   'text': 'Clad et al., 1982'},
#  'species_name': 'Mupapillomavirus 1',
#  'virus_id': 'HPV1'}

# %%
len(dict)
# Out:
# 448

# %%
    dict[45]
# Out:
# {'abbreviation': 'null',
#  'genbank': 'null',
#  'host_common_name': 'Human',
#  'host_scientific_name': 'Homo sapiens',
#  'ncbi_refseq': 'null',
#  'notes': 'null',
#  'pave_id': 'null',
#  'pave_name': 'null',
#  'reference': 'null',
#  'species_name': 'original HPV46 is HPV20 subtype',
#  'virus_id': 'HPV46'}

# %%
# Getting all pave_ids from dict
pave_ids = []
for item in dict:
    if item['pave_id'] != 'null':
        pave_ids.append(item['pave_id'])
    else:
        print(item['virus_id'] + ' has no pave_id instance')
# Out:
# HPV46 has no pave_id instance
# HPV55 has no pave_id instance
# HPV64 has no pave_id instance
# HPV79 has no pave_id instance
# HPV217 has no pave_id instance
# HPV218 has no pave_id instance

# %%
# For each HPV accesion open page and get relevant info
failedList = []
for item in pave_ids:

    URL = 'https://pave.niaid.nih.gov/locus_viewer?seq_id=' + item
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, "html")
    break

# %%
xpath = '/html/body/div[1]/div[1]/div[3]/div/div[2]/div[1]/div[2]/div/div/div[2]/svg/g[3]/g[7]/rect[1]'

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Firefox(executable_path=r'/home/pato/geckodriver')
driver.get(URL)
# Out:
# <ipython-input-13-e5b53ca54c14>:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(executable_path=r'/home/pato/geckodriver')

# %%
login_form = driver.find_element(By.XPATH, xpath)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-16-120764c0cad9> in <module>
# ----> 1 login_form = driver.find_element(By.XPATH, xpath)
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     853             value = '[name="%s"]' % value
#     854
# --> 855         return self.execute(Command.FIND_ELEMENT, {
#     856             'using': by,
#     857             'value': value})['value']
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     426         response = self.command_executor.execute(driver_command, params)
#     427         if response:
# --> 428             self.error_handler.check_response(response)
#     429             response['value'] = self._unwrap_value(
#     430                 response.get('value', None))
# ...

# %%
article = ''
for i in content.findAll('p'):
    article = article + ' ' +  i.text

# %%
article = ''
for i in content.findAll('p'):
    article = article + ' ' +  i.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-f676b463c868> in <module>
#       1 article = ''
# ----> 2 for i in content.findAll('p'):
#       3     article = article + ' ' +  i.text
#
# AttributeError: 'NoneType' object has no attribute 'findAll'

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <!-- Required meta tags -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <title>PaVE</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push(
#
# 	{'gtm.start': new Date().getTime(),event:'gtm.js'}
# 	);var f=d.getElementsByTagName(s)[0],
# 	j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 	'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 	})(window,document,'script','dataLayer','GTM-T2C8JDG');</script>
# <!-- End Google Tag Manager -->
# ...

# %%
failedList
# Out:
# ['HPV46', 'HPV55', 'HPV64', 'HPV79', 'HPV198', 'HPV217', 'HPV218']

# %%
hpvType in dict
    ncbiLink = dict[itemNumber]["genbank"]["link"]
    ncbiId = dict[itemNumber]["genbank"]["text"]
    hpvID = dict[itemNumber]["virus_id"]

# %%
newlist = []
for item in dict:
    hpvType = item['Type']
    subline = item['Sublineage']
    accID = item['NCBI Accession #']
    URL = 'https://ncbi.nlm.nih.gov/nuccore/' + accID + '.1?report=fasta'
    newlist.append([hpvType,subline,accID, URL])

# %%
# Now getting the ID/Val for the URL with the fasta
listOfFailed = []
for item in newlist:
    
    URL = item[3]
    #print(URL)
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, "xml")

    # Getting value for the fasta containing page
    idLine = soup.find(id='viewercontent1')
    idLine_str = str(idLine)
    NCBI_ID = re.search("val=\"[0-9]*\"", idLine_str)  # Finding value

    # testing that group object exists for reference on webpage
    try: 
        tester = NCBI_ID.group()  # getting matched value
    except:
        print(item)
        listOfFailed.append(item)
        continue

    NCBI_ID = NCBI_ID.group()  # getting matched value 
    NCBI_ID = NCBI_ID.replace("val=","")  # removing substring
    NCBI_ID = NCBI_ID.replace("\"","")  # removing substring
    
    # Tester for nyere versioner
    NCBI_ID2 = URL.replace(".1",".2")

    fastaPage = 'https://www.ncbi.nlm.nih.gov/sviewer/viewer.fcgi?id=' + NCBI_ID + '&db=nuccore&report=gff3'
    fastaPage2 = 'https://www.ncbi.nlm.nih.gov/sviewer/viewer.fcgi?id=' + NCBI_ID2 + '&db=nuccore&report=gff3'

    sequence = requests.get(fastaPage2)
    if sequence.status_code == 200:
        print("Found 2nd version")
    else:
        sequence = requests.get(fastaPage)


    # Saving fasta
    seq_str = str(sequence.content)
    seq_str = seq_str.replace("b\'","")  # Fjerner byte characterer
    seq_str = seq_str.replace("\'","")  # Fjerner byte characterer
    seq_str = seq_str.replace(r'\n', '\n') # håndterer \n så de bliver rigtige newlines
    seq_str = seq_str.replace(r'\t', '\t') # håndterer \t så de bliver rigtige newlines
    text_file = open(item[0]+'_'+item[2]+".gff3", "w")  # Åbner ny fil
    #print(item[2])
    text_file.write(seq_str.format()) # Gemmer fil

    for line in text_file:
        if not any('match'):
            newfile.write(line)

    text_file.close()
